# %%
import pandas as pd

# %%
df = pd.read_csv("scrapped_data.csv")

# %%
df = df[["Name","Price","Country","Date"]]

# %%
df.shape
# Out:
# (6000, 4)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (6000, 4)

# %%
# dropping null value columns to avoid errors
df.dropna(inplace = True)
 
# new data frame with split value columns
new = df["Name"].str.split("-", n = 1, expand = True)
 
# making separate first name column from new data frame
df["Product"]= new[0]
 
# making separate last name column from new data frame
df["Qty"]= new[1]
 
# Dropping old Name columns
df.drop(columns =["Name"], inplace = True)
 
# df display
df.head(20)
# Out:
#         Price Country                        Date  \
# 0     KSh 306   Kenya  2023-01-20 14:20:22.742117
# 1     KSh 153   Kenya  2023-01-20 14:20:22.742117
# 2     KSh 156   Kenya  2023-01-20 14:20:22.742117
# 3     KSh 310   Kenya  2023-01-20 14:20:22.742117
# 4     KSh 356   Kenya  2023-01-20 14:20:22.743076
# 5     KSh 128   Kenya  2023-01-20 14:20:22.743076
# 6   KSh 2,740   Kenya  2023-01-20 14:20:22.743076
# 7     KSh 324   Kenya  2023-01-20 14:20:22.743076
# 8     KSh 162   Kenya  2023-01-20 14:20:22.743076
# 9     KSh 297   Kenya  2023-01-20 14:20:22.743076
# 10    KSh 437   Kenya  2023-01-20 14:20:22.743076
# 11    KSh 455   Kenya  2023-01-20 14:20:22.743076
# 12    KSh 550   Kenya  2023-01-20 14:20:22.743076
# 13  KSh 4,200   Kenya  2023-01-20 14:20:22.743076
# 14    KSh 768   Kenya  2023-01-20 14:20:22.743076
# 15  KSh 1,180   Kenya  2023-01-20 14:20:22.743076
# 16  KSh 3,499   Kenya  2023-01-20 14:20:22.743076
# 17    KSh 824   Kenya  2023-01-20 14:20:22.743076
# 18  KSh 3,192   Kenya  2023-01-20 14:20:22.743076
# 19  KSh 1,250   Kenya  2023-01-20 14:20:22.743076
#
#                                               Product    Qty
# 0                  Kabras Kabras Premium White Sugar     2kg
# 1                  Kabras Kabras Premium White Sugar     1kg
# 2              Nutrameal Nutrameal Packed Sugar – 1Kg   None
# 3              Nutrameal Nutrameal Packed Sugar – 2Kg   None
# 4                           Kakira Light Brown Sugar     2kg
# 5                                Clovers Caster Sugar   500g
# 6   On Call PLUS GLUCOMETER + 50 STRIPS + 100 LANCETS   None
# 7                       Nutrameal Natural Cane Sugar     2kg
# 8                  Nutrameal Natural Wholesome Sugar     1Kg
# 9                     Naturalli Organic Coconut Sugar   None
# 10                           Canderel Sweetener Tabs     100
# 11                    Canderel Sweetener Stevia Tabs     100
# 12                         Canderel Sweetener Stevia     40g
# 13                Brown Sugar Sachets 1000pieces *6gm   None
# 14                         Canderel Sweetener Stevia    150g
# 15                        Nature'S Choice Coco Sugar    200g
# 16  On Call Plus GLUCOMETER FULL KIT ( Glucometer ...   None
# 17                                   Nutrameal Sugar     5kg
# 18                   Kabras Sugar 2 Kg X10 Pcs /1Bale   None
# 19         On Call Plus GLUCOSE TEST STRIPS WHOLESALE   None

# %%
df.tail(200)
# Out:
#          Price  Country                        Date  \
# 5800  ₦ 20,420  Nigeria  2023-01-20 14:22:59.026266
# 5801  ₦ 16,304  Nigeria  2023-01-20 14:22:59.026266
# 5802  ₦ 13,000  Nigeria  2023-01-20 14:22:59.026266
# 5803  ₦ 12,600  Nigeria  2023-01-20 14:22:59.026266
# 5804  ₦ 22,558  Nigeria  2023-01-20 14:22:59.026266
# ...        ...      ...                         ...
# 5995  ₦ 29,156  Nigeria  2023-01-20 14:23:03.854540
# 5996  ₦ 20,781  Nigeria  2023-01-20 14:23:03.854540
# 5997   ₦ 6,172  Nigeria  2023-01-20 14:23:03.854540
# 5998  ₦ 81,222  Nigeria  2023-01-20 14:23:03.854540
# 5999  ₦ 19,500  Nigeria  2023-01-20 14:23:03.854540
#
#                                                 Product  \
# 5800  Wholesale 6pcspack Diabetes Patch Reduce High ...
# 5801  Earlfamily 13cm X 10.2cm For Nurse Sugar Skull...
# 5802  Greenlife DB Formula (Dial B): Diabetes, High ...
# 5803                                     45 Pcsbox Semi
# 5804  OUTEST Digital Refractometer Beer Brix Wort Su...
# ...                                                 ...
# 5995                                          Shoe High
# 5996  Meibum Silicone Fondant Cake Mold Party Rose F...
# 5997  Priority Of 3 L Kinds Of Silica Mold Flip Suga...
# 5998  Vibla Return 2 Collection Nude Syrup Color  6 ...
# 5999         Glucometer Blood Sugar Monitor With Strips
#
#                                                     Qty
# 5800                                               None
# 5801                                               None
# 5802                                               None
# 5803            sugar Cold Drink Shop Series Decorative
# 5804                                               None
# ...                                                 ...
# 5995  Heeled Mold Candy Sugar Paste Chocolate Cake M...
# 5996                                               None
# 5997                                               None
# 5998                                               None
# 5999                                               None
#
# [200 rows x 5 columns]

# %%
# Cleaning the data

# delete all rows with column 'Qty' with a length > 40
df['Qty'] = df['Qty'].astype('str')
mask = (df['Qty'].str.len() <= 5)
df = df.loc[mask]
df.head()
# Out:
#      Price Country                        Date  \
# 0  KSh 306   Kenya  2023-01-20 14:20:22.742117
# 1  KSh 153   Kenya  2023-01-20 14:20:22.742117
# 2  KSh 156   Kenya  2023-01-20 14:20:22.742117
# 3  KSh 310   Kenya  2023-01-20 14:20:22.742117
# 4  KSh 356   Kenya  2023-01-20 14:20:22.743076
#
#                                   Product   Qty
# 0      Kabras Kabras Premium White Sugar    2kg
# 1      Kabras Kabras Premium White Sugar    1kg
# 2  Nutrameal Nutrameal Packed Sugar – 1Kg  None
# 3  Nutrameal Nutrameal Packed Sugar – 2Kg  None
# 4               Kakira Light Brown Sugar    2kg

# %%
df.head(100)
# Out:
#          Price Country                        Date  \
# 0      KSh 306   Kenya  2023-01-20 14:20:22.742117
# 1      KSh 153   Kenya  2023-01-20 14:20:22.742117
# 2      KSh 156   Kenya  2023-01-20 14:20:22.742117
# 3      KSh 310   Kenya  2023-01-20 14:20:22.742117
# 4      KSh 356   Kenya  2023-01-20 14:20:22.743076
# ..         ...     ...                         ...
# 118  KSh 1,150   Kenya  2023-01-20 14:20:25.186302
# 119  KSh 2,650   Kenya  2023-01-20 14:20:25.186302
# 121  KSh 1,600   Kenya  2023-01-20 14:20:26.186055
# 122  KSh 4,320   Kenya  2023-01-20 14:20:26.186055
# 123  KSh 2,800   Kenya  2023-01-20 14:20:26.186055
#
#                                                Product   Qty
# 0                   Kabras Kabras Premium White Sugar    2kg
# 1                   Kabras Kabras Premium White Sugar    1kg
# 2               Nutrameal Nutrameal Packed Sugar – 1Kg  None
# 3               Nutrameal Nutrameal Packed Sugar – 2Kg  None
# 4                            Kakira Light Brown Sugar    2kg
# ..                                                 ...   ...
# 118   Generic Seasoning Box Plastic Condiment Canister  None
# 119          On Call Plus Glucometer,Blood Sugar Meter  None
# 121  On Call Plus Glucometer Strips,Blood Sugar Met...  None
# 122  Generic Sealed Seasoning Bottle Set Glass Seas...  None
# 123          On Call Plus Blood Sugar Meter,Glucometer  None
#
# [100 rows x 5 columns]

# %%
#Drop columns containing None in Quantity

mask = (df['Qty'] != "None")
df = df.loc[mask]
df.head()
# Out:
#      Price Country                        Date  \
# 0  KSh 306   Kenya  2023-01-20 14:20:22.742117
# 1  KSh 153   Kenya  2023-01-20 14:20:22.742117
# 4  KSh 356   Kenya  2023-01-20 14:20:22.743076
# 5  KSh 128   Kenya  2023-01-20 14:20:22.743076
# 7  KSh 324   Kenya  2023-01-20 14:20:22.743076
#
#                               Product   Qty
# 0  Kabras Kabras Premium White Sugar    2kg
# 1  Kabras Kabras Premium White Sugar    1kg
# 4           Kakira Light Brown Sugar    2kg
# 5                Clovers Caster Sugar  500g
# 7       Nutrameal Natural Cane Sugar    2kg

# %%
df.tail(10)
# Out:
#           Price  Country                        Date  \
# 5592    ₦ 2,793  Nigeria  2023-01-20 14:22:52.398076
# 5632   ₦ 18,500  Nigeria  2023-01-20 14:22:53.122587
# 5672  ₦ 139,520  Nigeria  2023-01-20 14:22:54.326392
# 5711   ₦ 14,500  Nigeria  2023-01-20 14:22:55.065643
# 5778   ₦ 14,500  Nigeria  2023-01-20 14:22:58.030479
# 5832   ₦ 14,000  Nigeria  2023-01-20 14:22:59.028268
# 5890   ₦ 53,888  Nigeria  2023-01-20 14:23:01.684570
# 5910   ₦ 13,000  Nigeria  2023-01-20 14:23:01.685570
# 5922    ₦ 8,599  Nigeria  2023-01-20 14:23:02.765426
# 5940    ₦ 5,082  Nigeria  2023-01-20 14:23:02.766428
#
#                                                 Product    Qty
# 5592  Salt Spice Pepper Sugar Bottle Lid Seal Season...  White
# 5632       Dr Teal'S Shea Sugar Citrus Vitamin C Scrub    538g
# 5672  Digital Brix Sugar Refractometer Electronic Ha...
# 5711              Tree Hut Coco Colada Shea Sugar Scrub  18 Oz
# 5778                Tree Hut Vitamin C Shea Sugar Scrub  18 Oz
# 5832             Tree Hut Cotton Candy Shea Sugar Scrub  18 Oz
# 5890  Bluebont Bilberry Fruit Extract Gluten Free Su...    Cap
# 5910  Dr Teal'S Dr Teal’s Shea Sugar Citrus Vitamin ...   19OZ
# 5922  4Pcs/Set Cream Scraper Comb Plastic Turn Sugar...  White
# 5940  10Pcs Long Handle Wooden Spoon Salt Coffee Bea...   Wood

# %%
# Rename Product to Name

df.rename(columns={'Product':'Name'}, inplace=True)
# Convert datetype to string
df['Date']=df['Date'].astype(str)

# Using to_datetime() & astype()
df['Date']=pd.to_datetime(df['Date'].astype(str), format='%Y/%m/%d')

# Conver DataTime to Different Format
df['Date'] = df['Date'].dt.strftime('%d/%m/%Y')

# %%
# # Convert Date column to datetime
# df["Date"] = pd.to_datetime(df["Date"])

# %%
# Import sqlalchemy
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://root:root@localhost:5432/postgres")

# %%
engine.connect()
print("Pipeline connection to postgres successful...")
# Out:
# Pipeline connection to postgres successful...

# %%
print(pd.io.sql.get_schema(df, name='product', con=engine))
# Out:
# CREATE TABLE product (
# 	"Price" TEXT,
# 	"Country" TEXT,
# 	"Date" TIMESTAMP WITHOUT TIME ZONE,
# 	"Name" TEXT,
# 	"Qty" TEXT
# )

# %%
# Write the data to postgres
# Batch writes will not be immplemented since the dataset is small
print("Writing to database ...")
df.to_sql(name="product", con=engine, if_exists="append")
print("Write to postgres completed ....")
# Out:
# Writing to database ...
# Write to postgres completed ....

# %%
df.head()
# Out:
#      Price Country        Date                                Name   Qty
# 0  KSh 306   Kenya  20/01/2023  Kabras Kabras Premium White Sugar    2kg
# 1  KSh 153   Kenya  20/01/2023  Kabras Kabras Premium White Sugar    1kg
# 4  KSh 356   Kenya  20/01/2023           Kakira Light Brown Sugar    2kg
# 5  KSh 128   Kenya  20/01/2023                Clovers Caster Sugar  500g
# 7  KSh 324   Kenya  20/01/2023       Nutrameal Natural Cane Sugar    2kg
